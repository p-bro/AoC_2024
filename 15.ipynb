# %%
import numpy as np
directions=np.array([[1,0],[0,1],[-1,0],[0,-1]])
dirs='<>^v'
dirnums='3120'
dirtrans=str.maketrans(dirs,dirnums)
large

# %%
area=[]
oplist=[]
linecount = 0
with open('test_15b.txt') as f:
    for line in f:
        if len(line)<2:
            break
        area.append(list(line.strip().replace('.','..').replace('@','@.').replace('#','##').replace('O','[]')))
    for line in f:
        oplist.append(list(line.strip()))
maparr=np.array(area)
oparr=np.array(oplist).flatten()
ops=np.char.translate(oparr,dirtrans).astype(int)
dimx=maparr.shape[0]
dimy=maparr.shape[1]
robotx,roboty=np.where(maparr=='@')
robot=np.array([robotx[0],roboty[0]])
print(dimx,dimy,maparr,oparr,ops,robot)
maparr[robot[0],robot[1]]='.'
for i in range(dimx):
    print(''.join(maparr[i,:]))
# Out:
# 10 20 [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#'
#   '#' '#']
#  ['#' '#' '.' '.' '.' '.' '[' ']' '.' '.' '.' '.' '[' ']' '.' '.' '[' ']'
#   '#' '#']
#  ['#' '#' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '[' ']' '.' '.'
#   '#' '#']
#  ['#' '#' '.' '.' '[' ']' '[' ']' '.' '.' '.' '.' '[' ']' '.' '.' '[' ']'
#   '#' '#']
#  ['#' '#' '.' '.' '.' '.' '[' ']' '@' '.' '.' '.' '.' '.' '[' ']' '.' '.'
#   '#' '#']
#  ['#' '#' '[' ']' '#' '#' '.' '.' '.' '.' '[' ']' '.' '.' '.' '.' '.' '.'
#   '#' '#']
#  ['#' '#' '[' ']' '.' '.' '.' '.' '[' ']' '.' '.' '.' '.' '[' ']' '.' '.'
#   '#' '#']
#  ['#' '#' '.' '.' '[' ']' '[' ']' '.' '.' '[' ']' '.' '.' '[' ']' '[' ']'
#   '#' '#']
#  ['#' '#' '.' '.' '.' '.' '.' '.' '.' '.' '[' ']' '.' '.' '.' '.' '.' '.'
#   '#' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#'
#   '#' '#']] ['<' 'v' 'v' '>' '^' '<' 'v' '^' '>' 'v' '>' '^' 'v' 'v' '^' 'v' '>' 'v'
#  '<' '>' 'v' '^' 'v' '<' 'v' '<' '^' 'v' 'v' '<' '<' '<' '^' '>' '<' '<'
#  '>' '<' '>' '>' 'v' '<' 'v' 'v' 'v' '<' '>' '^' 'v' '^' '>' '^' '<' '<'
#  '<' '>' '<' '<' 'v' '<' '<' '<' 'v' '^' 'v' 'v' '^' 'v' '>' '^' 'v' 'v'
#  'v' '<' '<' '^' '>' '^' 'v' '^' '^' '>' '<' '<' '>' '>' '>' '<' '>' '^'
#  '<' '<' '>' '<' '^' 'v' 'v' '^' '^' '<' '>' 'v' 'v' 'v' '<' '>' '>' '<'
#  '^' '^' 'v' '>' '^' '>' 'v' 'v' '<' '>' 'v' '<' '<' '<' '<' 'v' '<' '^'
#  'v' '>' '^' '<' '^' '^' '>' '>' '>' '^' '<' 'v' '<' 'v' '>' '<' '>' 'v'
#  'v' '>' 'v' '^' 'v' '^' '<' '>' '>' '<' '>' '>' '>' '>' '<' '^' '^' '>'
#  'v' 'v' '>' 'v' '<' '^' '^' '^' '>' '>' 'v' '^' 'v' '^' '<' '^' '^' '>'
#  'v' '^' '^' '>' 'v' '^' '<' '^' 'v' '>' 'v' '<' '>' '>' 'v' '^' 'v' '^'
#  '<' 'v' '>' 'v' '^' '^' '<' '^' '^' 'v' 'v' '<' '<' '<' 'v' '<' '^' '>'
#  '>' '^' '^' '^' '^' '>' '>' '>' 'v' '^' '<' '>' 'v' 'v' 'v' '^' '>' '<'
#  'v' '<' '<' '<' '>' '^' '^' '^' 'v' 'v' '^' '<' 'v' 'v' 'v' '>' '^' '>'
#  'v' '<' '^' '^' '^' '^' 'v' '<' '>' '^' '>' 'v' 'v' 'v' 'v' '>' '<' '>'
#  '>' 'v' '^' '<' '<' '^' '^' '^' '^' '^' '^' '>' '<' '^' '>' '<' '>' '>'
#  '>' '<' '>' '^' '^' '<' '<' '^' '^' 'v' '>' '>' '>' '<' '^' '<' 'v' '>'
#  '^' '<' 'v' 'v' '>' '>' 'v' '>' '>' '>' '^' 'v' '>' '<' '>' '^' 'v' '>'
#  '<' '<' '<' '<' 'v' '>' '>' 'v' '<' 'v' '<' 'v' '>' 'v' 'v' 'v' '>' '^'
#  '<' '>' '<' '<' '>' '^' '>' '<' '^' '>' '>' '<' '>' '^' 'v' '<' '>' '<'
#  '^' 'v' 'v' 'v' '<' '^' '^' '<' '>' '<' 'v' '<' '<' '<' '<' '<' '>' '<'
#  '^' 'v' '<' '<' '<' '>' '<' '<' '<' '^' '^' '<' 'v' '<' '^' '^' '^' '>'
#  '<' '^' '>' '>' '^' '<' 'v' '^' '>' '<' '<' '<' '^' '>' '>' '^' 'v' '<'
#  'v' '^' 'v' '<' 'v' '^' '>' '^' '>' '>' '^' 'v' '>' 'v' 'v' '>' '^' '<'
#  '<' '^' 'v' '<' '>' '>' '<' '<' '>' '<' '<' 'v' '<' '<' 'v' '>' '<' '>'
#  'v' '<' '^' 'v' 'v' '<' '<' '<' '>' '^' '^' 'v' '^' '>' '^' '^' '>' '>'
#  '>' '<' '<' '^' 'v' '>' '>' 'v' '^' 'v' '>' '<' '^' '^' '>' '>' '^' '<'
#  '>' 'v' 'v' '^' '<' '>' '<' '^' '^' '>' '^' '^' '^' '<' '>' '<' 'v' 'v'
#  'v' 'v' 'v' '^' 'v' '<' 'v' '<' '<' '>' '^' 'v' '<' 'v' '>' 'v' '<' '<'
#  '^' '>' '<' '<' '>' '<' '<' '>' '<' '<' '<' '^' '^' '<' '<' '<' '^' '<'
#  '<' '>' '>' '<' '<' '>' '<' '^' '^' '^' '>' '^' '^' '<' '>' '^' '>' 'v'
#  '<' '>' '^' '^' '>' 'v' 'v' '<' '^' 'v' '^' 'v' '<' 'v' 'v' '>' '^' '<'
#  '>' '<' 'v' '<' '^' 'v' '>' '^' '^' '^' '>' '>' '>' '^' '^' 'v' 'v' 'v'
#  '^' '>' 'v' 'v' 'v' '<' '>' '>' '>' '^' '<' '^' '>' '>' '>' '>' '>' '^'
#  '<' '<' '^' 'v' '>' '^' 'v' 'v' 'v' '<' '>' '^' '<' '>' '<' '<' 'v' '>'
#  'v' '^' '^' '>' '>' '>' '<' '<' '^' '^' '<' '>' '>' '^' 'v' '^' '<' 'v'
#  '^' 'v' 'v' '<' '>' 'v' '^' '<' '<' '>' '^' '<' '^' 'v' '^' 'v' '>' '<'
#  '^' '<' '<' '<' '>' '<' '<' '^' '<' 'v' '>' '<' 'v' '<' '>' 'v' 'v' '>'
#  '>' 'v' '>' '<' 'v' '^' '<' 'v' 'v' '<' '>' 'v' '^' '<' '<' '^'] [3 0 0 1 2 3 0 2 1 0 1 2 0 0 2 0 1 0 3 1 0 2 0 3 0 3 2 0 0 3 3 3 2 1 3 3 1
#  3 1 1 0 3 0 0 0 3 1 2 0 2 1 2 3 3 3 1 3 3 0 3 3 3 0 2 0 0 2 0 1 2 0 0 0 3
#  3 2 1 2 0 2 2 1 3 3 1 1 1 3 1 2 3 3 1 3 2 0 0 2 2 3 1 0 0 0 3 1 1 3 2 2 0
#  1 2 1 0 0 3 1 0 3 3 3 3 0 3 2 0 1 2 3 2 2 1 1 1 2 3 0 3 0 1 3 1 0 0 1 0 2
#  0 2 3 1 1 3 1 1 1 1 3 2 2 1 0 0 1 0 3 2 2 2 1 1 0 2 0 2 3 2 2 1 0 2 2 1 0
#  2 3 2 0 1 0 3 1 1 0 2 0 2 3 0 1 0 2 2 3 2 2 0 0 3 3 3 0 3 2 1 1 2 2 2 2 1
#  1 1 0 2 3 1 0 0 0 2 1 3 0 3 3 3 1 2 2 2 0 0 2 3 0 0 0 1 2 1 0 3 2 2 2 2 0
#  3 1 2 1 0 0 0 0 1 3 1 1 0 2 3 3 2 2 2 2 2 2 1 3 2 1 3 1 1 1 3 1 2 2 3 3 2
#  2 0 1 1 1 3 2 3 0 1 2 3 0 0 1 1 0 1 1 1 2 0 1 3 1 2 0 1 3 3 3 3 0 1 1 0 3
#  0 3 0 1 0 0 0 1 2 3 1 3 3 1 2 1 3 2 1 1 3 1 2 0 3 1 3 2 0 0 0 3 2 2 3 1 3
#  0 3 3 3 3 3 1 3 2 0 3 3 3 1 3 3 3 2 2 3 0 3 2 2 2 1 3 2 1 1 2 3 0 2 1 3 3
#  3 2 1 1 2 0 3 0 2 0 3 0 2 1 2 1 1 2 0 1 0 0 1 2 3 3 2 0 3 1 1 3 3 1 3 3 0
#  3 3 0 1 3 1 0 3 2 0 0 3 3 3 1 2 2 0 2 1 2 2 1 1 1 3 3 2 0 1 1 0 2 0 1 3 2
#  2 1 1 2 3 1 0 0 2 3 1 3 2 2 1 2 2 2 3 1 3 0 0 0 0 0 2 0 3 0 3 3 1 2 0 3 0
#  1 0 3 3 2 1 3 3 1 3 3 1 3 3 3 2 2 3 3 3 2 3 3 1 1 3 3 1 3 2 2 2 1 2 2 3 1
#  2 1 0 3 1 2 2 1 0 0 3 2 0 2 0 3 0 0 1 2 3 1 3 0 3 2 0 1 2 2 2 1 1 1 2 2 0
#  0 0 2 1 0 0 0 3 1 1 1 2 3 2 1 1 1 1 1 2 3 3 2 0 1 2 0 0 0 3 1 2 3 1 3 3 0
#  1 0 2 2 1 1 1 3 3 2 2 3 1 1 2 0 2 3 0 2 0 0 3 1 0 2 3 3 1 2 3 2 0 2 0 1 3
#  2 3 3 3 1 3 3 2 3 0 1 3 0 3 1 0 0 1 1 0 1 3 0 2 3 0 0 3 1 0 2 3 3 2] [4 8]
# ####################
# ##....[]....[]..[]##
# ##............[]..##
# ##..[][]....[]..[]##
# ##....[]......[]..##
# ##[]##....[]......##
# ##[]....[]....[]..##
# ##..[][]..[]..[][]##
# ##........[]......##
# ####################

# %%
for op in ops:
    boxcount=0
    pushpos=[]
    print ('Try ',robot, op, directions[op], maparr[pos[0]+(boxcount+1)*directions[op][0],pos[1]+(boxcount+1)*directions[op][1]])
    pushpos.append(robot)
    pushdepth=1
    pushing=1
    while True:
        for push in pushpos:
            if maparr[push[0]+(pushdepth)*directions[op][0],push[1]+(boxcount+1)*directions[op][1]]=='[]'
        break
    while(maparr[pos[0]+(boxcount+1)*directions[op][0],pos[1]+(boxcount+1)*directions[op][1]]=='O'):
        #print('Found box',boxcount,' at ',pos[0]+(boxcount+1)*directions[op][0],pos[1]+(boxcount+1)*directions[op][1])
        boxcount+=1
    if maparr[pos[0]+(boxcount+1)*directions[op][0],pos[1]+(boxcount+1)*directions[op][1]]=='.':
        #print('Move',op,robot,boxcount,directions[op],pos[0]+(boxcount+1)*directions[op][0],pos[1]+(boxcount+1)*directions[op][1])
        robot=robot+directions[op]
        if boxcount:   
            maparr[pos[0]+(boxcount+1)*directions[op][0],pos[1]+(boxcount+1)*directions[op][1]]='O'
            maparr[pos[0]+directions[op][0],pos[1]+directions[op][1]]='.'
    #else:
        #print('No  ',op,robot)
    #maparr[robot[0],robot[1]]='@'
    #print(maparr,robot)
    #maparr[robot[0],robot[1]]='.'

# %%
maparr[robot[0],robot[1]]='@'
print(maparr)
cost=0
#print(np.where(maparr=='O'))

for box in np.transpose(np.where(maparr=='O')):
    print(box)
    cost += box[0]*100+box[1]
print (cost)
# Out:
# [['#' '#' '#' ... '#' '#' '#']
#  ['#' '#' '.' ... '.' '.' '#']
#  ['#' 'O' '.' ... '.' '.' '#']
#  ...
#  ['#' '.' '.' ... '#' 'O' '#']
#  ['#' 'O' 'O' ... 'O' '#' '#']
#  ['#' '#' '#' ... '#' '#' '#']]
# [1 3]
# [1 5]
# [1 6]
# [1 7]
# [1 8]
# [1 9]
# [ 1 11]
# [ 1 14]
# [ 1 15]
# [ 1 21]
# [ 1 22]
# [ 1 23]
# [ 1 24]
# [ 1 32]
# [ 1 33]
# [ 1 34]
# [ 1 36]
# [ 1 37]
# [ 1 38]
# [ 1 39]
# [ 1 40]
# [ 1 41]
# [2 1]
# [2 3]
# [2 5]
# [2 6]
# [2 7]
# [2 9]
# [ 2 11]
# [ 2 16]
# [ 2 19]
# [ 2 20]
# [ 2 21]
# [ 2 29]
# [ 2 30]
# [ 2 31]
# [ 2 32]
# [ 2 33]
# [ 2 34]
# [ 2 40]
# [ 2 41]
# [3 1]
# [3 4]
# [3 7]
# [ 3 26]
# [ 3 29]
# [ 3 32]
# [ 3 40]
# [ 3 41]
# [ 3 46]
# [39 16]
# [39 19]
# [39 26]
# [39 30]
# [39 31]
# [39 36]
# [39 38]
# [39 43]
# [39 46]
# [40  4]
# [40  5]
# [40 11]
# [40 13]
# [40 17]
# [40 21]
# [40 26]
# [40 35]
# [40 36]
# [40 39]
# [40 41]
# [41  2]
# [41  3]
# [41 13]
# [41 15]
# [41 18]
# [41 19]
# [41 22]
# [41 34]
# [41 36]
# [41 38]
# [41 41]
# [41 43]
# [41 45]
# [41 46]
# [41 47]
# [41 48]
# [42  3]
# [42  6]
# [42  9]
# [42 10]
# [42 13]
# [42 16]
# [42 29]
# [42 36]
# [42 44]
# [42 47]
# [42 48]
# [43 11]
# [43 12]
# [43 13]
# [43 27]
# [43 28]
# [43 31]
# [43 34]
# [44  2]
# [44  3]
# [44 24]
# [44 27]
# [44 28]
# [44 29]
# [44 37]
# [44 43]
# [44 44]
# [44 45]
# [45 10]
# [45 11]
# [45 12]
# [45 15]
# [45 24]
# [45 25]
# [45 26]
# [45 27]
# [45 28]
# [45 39]
# [45 40]
# [45 41]
# [45 42]
# [45 43]
# [45 44]
# [46  1]
# [46  2]
# [46 11]
# [46 14]
# [46 18]
# [46 20]
# [46 37]
# [46 38]
# [46 40]
# [46 47]
# [47  8]
# [47  9]
# [47 10]
# [47 11]
# [47 12]
# [47 15]
# [47 19]
# [47 23]
# [47 24]
# [47 25]
# [47 26]
# [47 32]
# [47 36]
# [47 37]
# [47 43]
# [47 48]
# [48  1]
# [48  2]
# [48  7]
# [48  8]
# [48  9]
# [48 13]
# [48 14]
# [48 17]
# [48 18]
# [48 19]
# [48 20]
# [48 22]
# [48 32]
# [48 34]
# [48 35]
# [48 36]
# [48 37]
# [48 38]
# [48 39]
# [48 41]
# [48 44]
# [48 47]
# 1492518

# %%
area=[]
oplist=[]
linecount = 0
with open('input_15.txt') as f:
    for line in f:
        if len(line)<2:
            break
        area.append(list(line.strip()))
    for line in f:
        oplist.append(list(line.strip()))
maparr=np.array(area)
oparr=np.array(oplist).flatten()
ops=np.char.translate(oparr,dirtrans).astype(int)
dimx=maparr.shape[0]
dimy=maparr.shape[1]
robotx,roboty=np.where(maparr=='@')
robot=np.array([robotx[0],roboty[0]])
print(dimx,dimy,maparr,oparr,ops,robot)
maparr[robot[0],robot[1]]='.'
print(maparr)

# %%
for op in ops:
    pos=robot.copy()
    boxcount=0
    #print ('Try ',robot, op, directions[op], maparr[pos[0]+(boxcount+1)*directions[op][0],pos[1]+(boxcount+1)*directions[op][1]])
    while(maparr[pos[0]+(boxcount+1)*directions[op][0],pos[1]+(boxcount+1)*directions[op][1]]=='O'):
        #print('Found box',boxcount,' at ',pos[0]+(boxcount+1)*directions[op][0],pos[1]+(boxcount+1)*directions[op][1])
        boxcount+=1
    if maparr[pos[0]+(boxcount+1)*directions[op][0],pos[1]+(boxcount+1)*directions[op][1]]=='.':
        #print('Move',op,robot,boxcount,directions[op],pos[0]+(boxcount+1)*directions[op][0],pos[1]+(boxcount+1)*directions[op][1])
        robot=robot+directions[op]
        if boxcount:   
            maparr[pos[0]+(boxcount+1)*directions[op][0],pos[1]+(boxcount+1)*directions[op][1]]='O'
            maparr[pos[0]+directions[op][0],pos[1]+directions[op][1]]='.'
    #else:
        #print('No  ',op,robot)
    #maparr[robot[0],robot[1]]='@'
    #print(maparr,robot)
    #maparr[robot[0],robot[1]]='.'
